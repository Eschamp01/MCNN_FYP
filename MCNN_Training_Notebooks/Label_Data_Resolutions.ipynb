# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import nibabel as nib
import glob

# %%
from google.colab import drive
import os

drive.mount('/content/drive', force_remount=True)
root_dir = "/content/drive/My Drive/"
project_folder = "FYP/MONAI_Lung/"
data_loc = "FYP/MONAI_Lung/Data/Task06_Lung/"
data_dir = root_dir + data_loc

def create_and_set_working_directory(project_folder):
  if os.path.isdir(root_dir + project_folder) == False:
    os.mkdir(root_dir + project_folder)
    print(root_dir + project_folder + ' did not exist but was created.')
  os.chdir(root_dir + project_folder)
  print('\nYour working directory was changed to ' + root_dir + project_folder)

create_and_set_working_directory(project_folder)
# Out:
# Mounted at /content/drive
#
# Your working directory was changed to /content/drive/My Drive/FYP/MONAI_Lung/

# %%
train_images = sorted(
    glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
train_labels = sorted(
    glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))
data_dicts = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(train_images, train_labels)
]
train_files, val_files = data_dicts[:-9], data_dicts[-9:]

# %%
from skimage.measure import block_reduce
def make_block_reduce( input_layers, dim=(2,2), mode=np.mean ):
    stacked_layers = [ block_reduce( image, dim, mode ) for image in input_layers ]
    return np.asarray( stacked_layers, dtype='float32' )

# %%
mri = nib.load(val_files[0]['label'])
test_data_array = mri.get_fdata()
print(test_data_array.shape)

data_arranged_1 = np.swapaxes(test_data_array,0,2)
data_arranged_2 = np.swapaxes(data_arranged_1,1,2)

test_slice = data_arranged_2[323, :, :]
unique, counts = np.unique(test_slice, return_counts=True)
label_dict = dict(zip(unique, counts))
print(label_dict[1])
print(label_dict[0])
print("ones percentage: ", ((label_dict[1]/(label_dict[1]+label_dict[0]))*100.0))
plt.imshow(test_slice.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()


test_data_array = make_block_reduce(data_arranged_2, (2,2), np.max)
test_slice = test_data_array[323, :, :]
unique, counts = np.unique(test_slice, return_counts=True)
label_dict = dict(zip(unique, counts))
print(label_dict[1])
print(label_dict[0])
print("ones percentage: ", ((label_dict[1]/(label_dict[1]+label_dict[0]))*100.0))
plt.imshow(test_slice.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()

test_data_array = make_block_reduce(test_data_array, (2,2), np.max)
test_slice = test_data_array[323, :, :]
unique, counts = np.unique(test_slice, return_counts=True)
label_dict = dict(zip(unique, counts))
print(label_dict[1])
print(label_dict[0])
print("ones percentage: ", ((label_dict[1]/(label_dict[1]+label_dict[0]))*100.0))
plt.imshow(test_slice.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()

test_data_array = make_block_reduce(test_data_array, (2,2), np.max)
test_slice = test_data_array[323, :, :]
unique, counts = np.unique(test_slice, return_counts=True)
label_dict = dict(zip(unique, counts))
print(label_dict[1])
print(label_dict[0])
print("ones percentage: ", ((label_dict[1]/(label_dict[1]+label_dict[0]))*100.0))
plt.imshow(test_slice.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()

test_data_array = make_block_reduce(test_data_array, (2,2), np.max)
test_slice = test_data_array[323, :, :]
unique, counts = np.unique(test_slice, return_counts=True)
label_dict = dict(zip(unique, counts))
print(label_dict[1])
print(label_dict[0])
print("ones percentage: ", ((label_dict[1]/(label_dict[1]+label_dict[0]))*100.0))
plt.imshow(test_slice.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()

test_data_array = make_block_reduce(test_data_array, (2,2), np.max)
test_slice = test_data_array[323, :, :]
unique, counts = np.unique(test_slice, return_counts=True)
label_dict = dict(zip(unique, counts))
print(label_dict[1])
print(label_dict[0])
print("ones percentage: ", ((label_dict[1]/(label_dict[1]+label_dict[0]))*100.0))
plt.imshow(test_slice.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()

test_data_array = make_block_reduce(test_data_array, (2,2), np.max)
test_slice = test_data_array[323, :, :]
unique, counts = np.unique(test_slice, return_counts=True)
label_dict = dict(zip(unique, counts))
print(label_dict[1])
print(label_dict[0])
print("ones percentage: ", ((label_dict[1]/(label_dict[1]+label_dict[0]))*100.0))
plt.imshow(test_slice.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()

test_data_array = make_block_reduce(test_data_array, (2,2), np.max)
test_slice = test_data_array[323, :, :]
unique, counts = np.unique(test_slice, return_counts=True)
label_dict = dict(zip(unique, counts))
print(label_dict[1])
print(label_dict[0])
print("ones percentage: ", ((label_dict[1]/(label_dict[1]+label_dict[0]))*100.0))
plt.imshow(test_slice.T, cmap='gray', origin='lower')
plt.xlabel('First axis')
plt.ylabel('Second axis')
plt.colorbar(label='Signal intensity')
plt.show()
# Out:
# (512, 512, 450)
# 294
# 261850
# ones percentage:  0.112152099609375
# 82
# 65454
# ones percentage:  0.1251220703125
# 24
# 16360
# ones percentage:  0.146484375
# 8
# 4088
# ones percentage:  0.1953125
# 2
# 1022
# ones percentage:  0.1953125
# 1
# 255
# ones percentage:  0.390625
# 1
# 63
# ones percentage:  1.5625
# 1
# 15
# ones percentage:  6.25
